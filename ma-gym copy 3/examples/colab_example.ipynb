# %% [markdown]
# # **Dependency Setup**

# %%
# !pip install --root-user-action=ignore 'pip<=23.0.1'
# !pip install --root-user-action=ignore 'setuptools<=66'
# !pip install --root-user-action=ignore 'wheel<=0.38.4'
# !pip install --root-user-action=ignore ma-gym
# Out:
# Collecting pip<=23.0.1
#   Downloading pip-23.0.1-py3-none-any.whl.metadata (4.1 kB)
# Downloading pip-23.0.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 16.1 MB/s eta 0:00:0000:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.0
#     Uninstalling pip-24.0:
#       Successfully uninstalled pip-24.0
# Successfully installed pip-23.0.1
#
# [notice] A new release of pip is available: 23.0.1 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# ERROR: Exception:
# Traceback (most recent call last):
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/cli/base_command.py", line 160, in exc_logging_wrapper
#     status = run_func(*args)
#              ^^^^^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/cli/req_command.py", line 247, in wrapper
#     return func(self, options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/commands/install.py", line 345, in run
#     session = self.get_default_session(options)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/cli/req_command.py", line 98, in get_default_session
#     self._session = self.enter_context(self._build_session(options))
#                                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/cli/req_command.py", line 125, in _build_session
#     session = PipSession(
#               ^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/network/session.py", line 343, in __init__
#     self.headers["User-Agent"] = user_agent()
#                                  ^^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/network/session.py", line 175, in user_agent
#     setuptools_dist = get_default_environment().get_distribution("setuptools")
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/metadata/importlib/_envs.py", line 188, in get_distribution
#     return next(matches, None)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/metadata/importlib/_envs.py", line 183, in <genexpr>
#     matches = (
#               ^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/metadata/base.py", line 612, in iter_all_distributions
#     for dist in self._iter_distributions():
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/metadata/importlib/_envs.py", line 176, in _iter_distributions
#     for dist in finder.find_eggs(location):
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/metadata/importlib/_envs.py", line 144, in find_eggs
#     yield from self._find_eggs_in_dir(location)
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/metadata/importlib/_envs.py", line 111, in _find_eggs_in_dir
#     from pip._vendor.pkg_resources import find_distributions
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_vendor/pkg_resources/__init__.py", line 2164, in <module>
#     register_finder(pkgutil.ImpImporter, find_on_path)
#                     ^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'pkgutil' has no attribute 'ImpImporter'. Did you mean: 'zipimporter'?
# Traceback (most recent call last):
#   File "/home/osuke/miniconda3/envs/ma-gym/bin/pip", line 8, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/cli/main.py", line 70, in main
#     return command.main(cmd_args)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/cli/base_command.py", line 101, in main
#     return self._main(args)
#            ^^^^^^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/cli/base_command.py", line 216, in _main
#     self.handle_pip_version_check(options)
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/cli/req_command.py", line 179, in handle_pip_version_check
#     session = self._build_session(
#               ^^^^^^^^^^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/cli/req_command.py", line 125, in _build_session
#     session = PipSession(
#               ^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/network/session.py", line 343, in __init__
#     self.headers["User-Agent"] = user_agent()
#                                  ^^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/network/session.py", line 175, in user_agent
#     setuptools_dist = get_default_environment().get_distribution("setuptools")
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/metadata/importlib/_envs.py", line 188, in get_distribution
#     return next(matches, None)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/metadata/importlib/_envs.py", line 183, in <genexpr>
#     matches = (
#               ^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/metadata/base.py", line 612, in iter_all_distributions
#     for dist in self._iter_distributions():
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/metadata/importlib/_envs.py", line 176, in _iter_distributions
#     for dist in finder.find_eggs(location):
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/metadata/importlib/_envs.py", line 144, in find_eggs
#     yield from self._find_eggs_in_dir(location)
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/metadata/importlib/_envs.py", line 111, in _find_eggs_in_dir
#     from pip._vendor.pkg_resources import find_distributions
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_vendor/pkg_resources/__init__.py", line 2164, in <module>
#     register_finder(pkgutil.ImpImporter, find_on_path)
#                     ^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'pkgutil' has no attribute 'ImpImporter'. Did you mean: 'zipimporter'?
# ERROR: Exception:
# Traceback (most recent call last):
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/cli/base_command.py", line 160, in exc_logging_wrapper
#     status = run_func(*args)
#              ^^^^^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/cli/req_command.py", line 247, in wrapper
#     return func(self, options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/commands/install.py", line 345, in run
#     session = self.get_default_session(options)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/cli/req_command.py", line 98, in get_default_session
#     self._session = self.enter_context(self._build_session(options))
#                                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/cli/req_command.py", line 125, in _build_session
#     session = PipSession(
#               ^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/network/session.py", line 343, in __init__
#     self.headers["User-Agent"] = user_agent()
#                                  ^^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/network/session.py", line 175, in user_agent
#     setuptools_dist = get_default_environment().get_distribution("setuptools")
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/metadata/importlib/_envs.py", line 188, in get_distribution
#     return next(matches, None)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/metadata/importlib/_envs.py", line 183, in <genexpr>
#     matches = (
#               ^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/metadata/base.py", line 612, in iter_all_distributions
#     for dist in self._iter_distributions():
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/metadata/importlib/_envs.py", line 176, in _iter_distributions
#     for dist in finder.find_eggs(location):
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/metadata/importlib/_envs.py", line 144, in find_eggs
#     yield from self._find_eggs_in_dir(location)
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/metadata/importlib/_envs.py", line 111, in _find_eggs_in_dir
#     from pip._vendor.pkg_resources import find_distributions
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_vendor/pkg_resources/__init__.py", line 2164, in <module>
#     register_finder(pkgutil.ImpImporter, find_on_path)
#                     ^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'pkgutil' has no attribute 'ImpImporter'. Did you mean: 'zipimporter'?
# Traceback (most recent call last):
#   File "/home/osuke/miniconda3/envs/ma-gym/bin/pip", line 8, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/cli/main.py", line 70, in main
#     return command.main(cmd_args)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/cli/base_command.py", line 101, in main
#     return self._main(args)
#            ^^^^^^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/cli/base_command.py", line 216, in _main
#     self.handle_pip_version_check(options)
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/cli/req_command.py", line 179, in handle_pip_version_check
#     session = self._build_session(
#               ^^^^^^^^^^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/cli/req_command.py", line 125, in _build_session
#     session = PipSession(
#               ^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/network/session.py", line 343, in __init__
#     self.headers["User-Agent"] = user_agent()
#                                  ^^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/network/session.py", line 175, in user_agent
#     setuptools_dist = get_default_environment().get_distribution("setuptools")
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/metadata/importlib/_envs.py", line 188, in get_distribution
#     return next(matches, None)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/metadata/importlib/_envs.py", line 183, in <genexpr>
#     matches = (
#               ^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/metadata/base.py", line 612, in iter_all_distributions
#     for dist in self._iter_distributions():
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/metadata/importlib/_envs.py", line 176, in _iter_distributions
#     for dist in finder.find_eggs(location):
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/metadata/importlib/_envs.py", line 144, in find_eggs
#     yield from self._find_eggs_in_dir(location)
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/metadata/importlib/_envs.py", line 111, in _find_eggs_in_dir
#     from pip._vendor.pkg_resources import find_distributions
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_vendor/pkg_resources/__init__.py", line 2164, in <module>
#     register_finder(pkgutil.ImpImporter, find_on_path)
#                     ^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'pkgutil' has no attribute 'ImpImporter'. Did you mean: 'zipimporter'?
# ERROR: Exception:
# Traceback (most recent call last):
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/cli/base_command.py", line 160, in exc_logging_wrapper
#     status = run_func(*args)
#              ^^^^^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/cli/req_command.py", line 247, in wrapper
#     return func(self, options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/commands/install.py", line 345, in run
#     session = self.get_default_session(options)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/cli/req_command.py", line 98, in get_default_session
#     self._session = self.enter_context(self._build_session(options))
#                                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/cli/req_command.py", line 125, in _build_session
#     session = PipSession(
#               ^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/network/session.py", line 343, in __init__
#     self.headers["User-Agent"] = user_agent()
#                                  ^^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/network/session.py", line 175, in user_agent
#     setuptools_dist = get_default_environment().get_distribution("setuptools")
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/metadata/importlib/_envs.py", line 188, in get_distribution
#     return next(matches, None)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/metadata/importlib/_envs.py", line 183, in <genexpr>
#     matches = (
#               ^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/metadata/base.py", line 612, in iter_all_distributions
#     for dist in self._iter_distributions():
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/metadata/importlib/_envs.py", line 176, in _iter_distributions
#     for dist in finder.find_eggs(location):
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/metadata/importlib/_envs.py", line 144, in find_eggs
#     yield from self._find_eggs_in_dir(location)
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/metadata/importlib/_envs.py", line 111, in _find_eggs_in_dir
#     from pip._vendor.pkg_resources import find_distributions
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_vendor/pkg_resources/__init__.py", line 2164, in <module>
#     register_finder(pkgutil.ImpImporter, find_on_path)
#                     ^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'pkgutil' has no attribute 'ImpImporter'. Did you mean: 'zipimporter'?
# Traceback (most recent call last):
#   File "/home/osuke/miniconda3/envs/ma-gym/bin/pip", line 8, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/cli/main.py", line 70, in main
#     return command.main(cmd_args)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/cli/base_command.py", line 101, in main
#     return self._main(args)
#            ^^^^^^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/cli/base_command.py", line 216, in _main
#     self.handle_pip_version_check(options)
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/cli/req_command.py", line 179, in handle_pip_version_check
#     session = self._build_session(
#               ^^^^^^^^^^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/cli/req_command.py", line 125, in _build_session
#     session = PipSession(
#               ^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/network/session.py", line 343, in __init__
#     self.headers["User-Agent"] = user_agent()
#                                  ^^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/network/session.py", line 175, in user_agent
#     setuptools_dist = get_default_environment().get_distribution("setuptools")
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/metadata/importlib/_envs.py", line 188, in get_distribution
#     return next(matches, None)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/metadata/importlib/_envs.py", line 183, in <genexpr>
#     matches = (
#               ^
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/metadata/base.py", line 612, in iter_all_distributions
#     for dist in self._iter_distributions():
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/metadata/importlib/_envs.py", line 176, in _iter_distributions
#     for dist in finder.find_eggs(location):
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/metadata/importlib/_envs.py", line 144, in find_eggs
#     yield from self._find_eggs_in_dir(location)
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_internal/metadata/importlib/_envs.py", line 111, in _find_eggs_in_dir
#     from pip._vendor.pkg_resources import find_distributions
#   File "/home/osuke/miniconda3/envs/ma-gym/lib/python3.12/site-packages/pip/_vendor/pkg_resources/__init__.py", line 2164, in <module>
#     register_finder(pkgutil.ImpImporter, find_on_path)
#                     ^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'pkgutil' has no attribute 'ImpImporter'. Did you mean: 'zipimporter'?

# %% [markdown]
# # **Demo Run:**

# %%
import gym

env = gym.make('ma_gym:Switch2-v0')
done_n = [False for _ in range(env.n_agents)]
ep_reward = 0

obs_n = env.reset()
while not all(done_n):
    obs_n, reward_n, done_n, info = env.step(env.action_space.sample())
    ep_reward += sum(reward_n)
env.close()
print(f'Episode Return:{ep_reward:.2f}')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import gym
#       3 env = gym.make('ma_gym:Switch2-v0')
#       4 done_n = [False for _ in range(env.n_agents)]
#
# ModuleNotFoundError: No module named 'gym'
