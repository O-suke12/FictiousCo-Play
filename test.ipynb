# %%
import torch.nn as nn
import torch

rnn = nn.RNN(10, 20, 2)
input = torch.randn(5, 3, 10)
h0 = torch.randn(2, 3, 20)
output, hn = rnn(input, h0)

# %%
input
# Out:
# tensor([[[-1.1801,  0.8299, -0.0282, -2.1844,  1.1956,  0.1456,  0.0117,
#           -0.0459,  1.3119, -1.9924],
#          [-0.5364,  0.7858, -1.4040,  0.6087,  1.0025,  0.0991,  0.5145,
#           -1.3576,  0.1984, -0.5873],
#          [-0.3678, -0.1105,  0.2567, -0.3553,  0.1819, -1.1678,  1.1311,
#           -0.7657,  0.8481, -0.5467]],
#
#         [[ 0.3533, -0.4646,  1.0333,  0.4632, -0.7209,  0.3342, -0.2955,
#            0.7292,  0.1085, -0.4982],
#          [-1.4712,  0.4481, -1.0792,  1.8173,  0.9086, -1.1946,  0.8278,
#            0.0229,  0.5370,  0.8707],
#          [ 0.9680,  1.6953,  1.4846,  0.1818,  0.9719,  2.1867, -1.2991,
#           -0.8456, -0.5216, -1.1690]],
#
#         [[ 0.1218, -0.1493, -0.4120,  1.2187, -1.9694,  0.4863,  1.9005,
#           -1.2763, -0.0288,  0.8580],
#          [-0.7376,  0.0049,  0.3284, -2.5985, -1.7173,  0.2948, -0.6579,
#           -1.7345,  0.1942,  0.2133],
# ...
